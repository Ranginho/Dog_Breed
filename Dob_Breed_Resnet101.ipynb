# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np 
import pandas as pd
import os
import cv2
from tqdm import tqdm
from random import shuffle
import pickle
import random

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop

IMG_SHAPE = 224

datagen = ImageDataGenerator(
    rescale=1./255.,
    rotation_range = 40,
    zoom_range = 0.2,
    horizontal_flip = True
    )

train_generator = datagen.flow_from_directory(
        'drive/MyDrive/dog-breed-identification/train_labeled',
        target_size=(IMG_SHAPE, IMG_SHAPE),
        batch_size=32,
        class_mode='categorical',
        seed=42,
        shuffle=True,)
        

validation_generator = datagen.flow_from_directory(
        'drive/MyDrive/dog-breed-identification/valid_folders',
        target_size=(IMG_SHAPE, IMG_SHAPE),
        batch_size=32,
        class_mode='categorical',
        seed=42,
        shuffle=True,)
# Out:
# Mounted at /content/drive
# Found 10222 images belonging to 120 classes.
# Found 1680 images belonging to 120 classes.

# %%
resnet = tf.keras.applications.ResNet101V2(input_shape = [IMG_SHAPE,IMG_SHAPE,3], weights = 'imagenet', include_top = False)

for layer in resnet.layers:
    layer.trainable = False

x = tf.keras.layers.Flatten()(resnet.output)
pred = tf.keras.layers.Dense(120, activation='softmax')(x)
model = tf.keras.models.Model(inputs=resnet.input, outputs=pred)

opt = tf.keras.optimizers.Adam(learning_rate = 1e-4)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
train_step = 200

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# ...

# %%
resnet101 = model.fit(train_generator,validation_data = validation_generator,epochs = 20,steps_per_epoch = 200)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 168s 803ms/step - loss: 5.9327 - accuracy: 0.1081 - val_loss: 3.7621 - val_accuracy: 0.2708
# Epoch 2/20
# 200/200 [==============================] - 156s 781ms/step - loss: 3.1220 - accuracy: 0.3450 - val_loss: 2.5873 - val_accuracy: 0.4268
# Epoch 3/20
# 200/200 [==============================] - 158s 791ms/step - loss: 2.4031 - accuracy: 0.4541 - val_loss: 2.0529 - val_accuracy: 0.5012
# Epoch 4/20
# 200/200 [==============================] - 158s 790ms/step - loss: 1.9810 - accuracy: 0.5371 - val_loss: 1.7969 - val_accuracy: 0.5768
# Epoch 5/20
# 200/200 [==============================] - 158s 792ms/step - loss: 1.7219 - accuracy: 0.5922 - val_loss: 1.5766 - val_accuracy: 0.6107
# Epoch 6/20
# 200/200 [==============================] - 160s 801ms/step - loss: 1.4935 - accuracy: 0.6298 - val_loss: 1.4227 - val_accuracy: 0.6583
# Epoch 7/20
# ...

# %%
resnet101 = model.fit(train_generator,validation_data = validation_generator,epochs = 20,steps_per_epoch = 200)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 1953s 10s/step - loss: 4.5353 - accuracy: 0.3920 - val_loss: 2.8243 - val_accuracy: 0.6012
# Epoch 2/20
# 200/200 [==============================] - 627s 3s/step - loss: 2.9271 - accuracy: 0.5977 - val_loss: 2.5691 - val_accuracy: 0.6518
# Epoch 3/20
# 200/200 [==============================] - 346s 2s/step - loss: 2.5051 - accuracy: 0.6595 - val_loss: 1.9717 - val_accuracy: 0.7155
# Epoch 4/20
# 200/200 [==============================] - 215s 1s/step - loss: 2.3124 - accuracy: 0.6973 - val_loss: 2.0461 - val_accuracy: 0.7232
# Epoch 5/20
# 200/200 [==============================] - 184s 919ms/step - loss: 2.0301 - accuracy: 0.7337 - val_loss: 1.8257 - val_accuracy: 0.7488
# Epoch 6/20
# 200/200 [==============================] - 166s 829ms/step - loss: 1.8938 - accuracy: 0.7474 - val_loss: 1.7275 - val_accuracy: 0.7810
# Epoch 7/20
# ...

# %%
model.save("resnet101.h5")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
resnet101 = model.fit(train_generator,validation_data = validation_generator,epochs = 20,steps_per_epoch = 200)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 165s 827ms/step - loss: 0.9668 - accuracy: 0.8840 - val_loss: 0.9852 - val_accuracy: 0.8869
# Epoch 2/20
# 200/200 [==============================] - 167s 832ms/step - loss: 0.9473 - accuracy: 0.8858 - val_loss: 0.8233 - val_accuracy: 0.9000
# Epoch 3/20
# 200/200 [==============================] - 165s 827ms/step - loss: 0.9364 - accuracy: 0.8931 - val_loss: 1.0402 - val_accuracy: 0.8815
# Epoch 4/20
# 200/200 [==============================] - 165s 824ms/step - loss: 0.8898 - accuracy: 0.8913 - val_loss: 0.8039 - val_accuracy: 0.9101
# Epoch 5/20
# 200/200 [==============================] - 164s 819ms/step - loss: 0.8564 - accuracy: 0.8950 - val_loss: 0.8067 - val_accuracy: 0.8970
# Epoch 6/20
# 200/200 [==============================] - 166s 830ms/step - loss: 0.9116 - accuracy: 0.8917 - val_loss: 0.7722 - val_accuracy: 0.9089
# Epoch 7/20
# ...
